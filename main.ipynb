# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('state_cpi.xls')
df.head()
# Out:
# _locate_stream(Workbook): seen
#     0  5 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#    20  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#   480= 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#   500  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 3 2 2 2 2
#   520  2
# ---------------------------------------------------------------------------
# CompDocError                              Traceback (most recent call last)
# /home/samar/Desktop/cpi/main.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/samar/Desktop/cpi/main.ipynb#ch0000001?line=0'>1</a> df = pd.read_excel('state_cpi.xls')
#       <a href='vscode-notebook-cell:/home/samar/Desktop/cpi/main.ipynb#ch0000001?line=1'>2</a> df.head()
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...
